# %%
#3.1
#How many seconds are in an hour?

number = 60 * 60
print(number)
# Out:
# 3600

# %%
#3.2
#Assign previous result to a variable.

seconds_per_hour = 3600
print(seconds_per_hour)
# Out:
# 3600

# %%
#3.3
#How many seconds are in a day?

seconds_per_hour = 3600
two_four_seven_seconds = seconds_per_hour * 24
print(two_four_seven_seconds)
# Out:
# 86400

# %%
#3.4
#Assign previous result to a variable.

seconds_per_hour = 3600
seconds_per_day = seconds_per_hour * 24
print(seconds_per_day)
# Out:
# 86400

# %%
#3.5
#Division.

number_two = seconds_per_day / seconds_per_hour
print(number_two)
# Out:
# 24.0

# %%
#3.6
#perform 3.5 again, but with floor division.

number_two = seconds_per_day // seconds_per_hour
print(number_two)
# Out:
# 24

# %% [markdown]
# Did this number agree with the floating-point value from the previous question, aside from the final .0? Yes.
